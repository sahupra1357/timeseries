# %% [markdown]
# <p align="center">
# <img src = "https://www.ensodata.com/wp-content/uploads/2022/02/ensodata-logo.svg">
# </p>
#
# # **Forecasting Future Continuous Positive Airway Pressure (CPAP) usage**
#
#
# ---
#
#
# Welcome to your AI evaluation!
#
# We are excited to offer you this opportunity to showcase your skills in the following task which was tailored to the Machine Learning Engineer job requirements. The tasks also evaluates your ability to learn specific domain topics that are required for the successful completion of this technical evaluation. Make sure you fully read all of the descriptions below before diving into your evaluation.
#
# # **The Tasks:**
# #### **Task 1 - Frequantly Asked Questions:**
# Review the following FAQ about sleep apnea to ensure that you gain all of the domain knowledge necessary for this evaluation.
#
# #### **Task 2 - Feature Engineering and Helper Functions:**
# Implement several functions that will assist you in ensuring that the provided dataset is ready for the following tasks, as well as plots that will assist you with evaluating your methods.
#
# #### **Task 3 - Implement a Naive (not Bayes) CPAP Adherence Forecasting Algorithm:**
# Implement a basic way to forecast CPAP adherence. This forecasting assumes that the amount of hours the patient is going to use the CPAP machine the next day is equal to the number of hours the patient used the CPAP machine the previous day.
#
# #### **Task 4 - Train a Machine Learning Model for CPAP Adherence Forecasting:**
# Choose an appropriate machine learning algorithm and train a model to forecast future CPAP adherence.
#
# #### **Task 5 - Train a Deep Learning Model for CPAP Adherence Forecasting:**
# Use tf.keras to design an appropriate deep learning model and train it to forecast future CPAP adherence.
#
# #### **Task 6 - Discussion:**
# Discuss your results and implementation. Compare all methods from tasks 3-5.
#
# # **Dataset Description:**
#
# You will find two data frames returned from the read_csv() function below. They contain the data to be used for training and testing respectively and have a similar structure of features. The columns in the original CSV file are:
#
# * ***UID***: A unique ID of the patient
# * ***Age***: The age of the patient
# * ***Sex***: The sex of the patient
# * ***AHI***: The apnea-hypopnea index of the patient
# * ***Day 1-455***: The number of minutes the patient used the CPAP during each day
#
#
# # **Notebook Description:**
#
# Below you will find pre-added code blocks. Some of them are pre-filled and some of them you will need to fill in yourself. Above each code block, you will have further information and instructions.
#
# After the evaluation is completed, please prepare a report showing the relevant plots and conclusions for each task. This should be slides or a document that summarizes the work and will facilitate a high-level discussion of your approach and principal results. You will have the opportunity to present your conclusions to the team in a follow-up call after your submission.
#
# Once you are finished with this task, please send the report (.PDF) and all IPython notebooks to yoav@ensodata.com. Make sure that they are in full running condition.
#
# All questions should be directed to yoav@ensodata.com
#
#
# Good luck!
#
#
# The EnsoData AI Team 🍍🍍🍍

# %% [markdown]
# #Task 1 - Frequently Asked Questions
# Review the following FAQ. If you have any additional questions regarding sleep apnea that you feel is needed to successfully complete this evaluation, please reach out to yoav@ensodata.com
#
# 1. ***Q:*** What is sleep apnea?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: Sleep apnea refers to the condition where an individual's breathing frequently stops and starts throughout the night.
# 2. ***Q:*** What is the physiological mechanism of sleep apnea?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: There are two main types of sleep apnea, both result in frequent cessation of breathing during the night. The most common type is obstructive sleep apnea (OSA). OSA is caused by blockage of the airway when the soft tissue in the back of the throat collapses during sleep. The second type is central sleep apnea (CSA). CSA occurs when the brain fails to tell the lungs to breathe during sleep. As this signal is lost, the lungs do not take in the air that the body needs.
# 3. ***Q:*** What is the current prevalence of sleep apnea in the U.S?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: Sleep apnea affects approximately 26% of US adults, of whom about 90% are undiagnosed.
# 4. ***Q:*** How is sleep apnea diagnosed?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: Based on patient symptoms and sleep history (reported by either the patient or by the person who shares the patient's bed or household) they may be referred to a sleep disorders clinic. The patient will typically undergo a polysomnography (PSG) or a home sleep apnea test (HSAT) which monitors the patient overnight, recording various types of physiological signals such as electroencephalogram (EEG; monitors brain function), nasal flow (monitors airflow during sleep), abdomen and/or chest effort (monitors the contraction and expansion of the abdomen or chest), blood oxygen level (monitors the oxygen levels in the blood), electromyography (EMG; monitors leg movements), and potentially other signals as well. The full night recording is then typically reviewed by a Registered Polysomnographic Technologist (RPSGT), assessing the total amount of hours the patient slept, as well as identifying all of the instances where the patient either stopped breathing completely (apnea) or had a decrease in airflow (hypopnea) during the night. Based on the results of this test, the physician is then able to diagnose the patient with having sleep apnea and recommends the next steps for treatment.
# 5. ***Q:*** What is the Apnea-Hypopnea Index (AHI) and how is it used to diagnose sleep apnea severity? How many sleep apnea severity levels are there?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: The AHI is calculated by counting the number of instances the patient had apneas and hypopneas, and dividing that number by the total amount of hours the patient slept during the night. The AHI is used to generate a diagnosis for the patient. If the patient has an AHI of less than 5 events/hour, the patient receives a negative diagnosis. If the patient has an AHI of 5-15 events/hour, the patient is diagnosed with mild sleep apnea. If the patient has an AHI of 15-30 events/hour, the patient is diagnosed with moderate sleep apnea. If the patient has an AHI greater than 30, the patient is diagnosed with severe sleep apnea. Based on the severity of the diagnosis, the physician can recommend different types of sleep apnea treatments.
# 6. ***Q:*** What are potential treatments for sleep apnea?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: One option is Continous Positive Airway Pressure (CPAP). CPAP is used to treat obstructive sleep apnea by transmitting pressurized air through the nose, mouth, or both, which applies pressure on the airway to reduce the likelihood the airway will collapse and obstruct breathing. Another treatment option is hypoglossal nerve stimulation (HGNS). HGNS is an implantable device that connects via an electrode to the hypoglossal nerve and utilizing electrical stimulation, stimulates the hypoglossal nerve which relieves upper airway obstruction by triggering tongue movements. Other treatments include various mouth and nose appliances, structural mouth and throat surgery, as well as life changes such as weight loss.
# 8. ***Q:*** How does medicare define compliance for a CPAP machine?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: A patient is compliant with a CPAP machine if they use the machine for more than 4 hours for at least 70% of the days over the course of 90 days.
# 9. ***Q:*** What percentage of patients are compliant with a CPAP machine?<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A: Studies show that somewhere between 29% and 83% of patients do not meet the criteria for compliance due to removing the CPAP early in the night and/or skipping use altogether. Thus, being able to forecast when a patient is about to become non-compliant with the CPAP machine may allow clinicians to identify struggling patients. The clinicians can then reach out to the patients and support them in such a way that will increase their likelihood of becoming compliant with the CPAP machine.

# %% [markdown]
# # Task 2 - Feature Engineering and Helper Functions:

# %% [markdown]
# ###Import all libraries and install any additional libraries:
#
# ***Add here any additional installations and package imports that you need for your implementation***

# %%
import importlib
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import seaborn as sns
import scipy.odr as odr
from scipy.stats import linregress
import gc
import time

# %% [markdown]
# ## Initialize TPU
# In task 5 you'll be training a Deep Learning model using TPUs. Below you'll find pre-added code that initializes the TPU for you. Before running the block below, you should enable TPUs in this notebook. Go to the menu at the top of this notebook and select Runtime -> change runtime type -> set the hardware accelerator as TPU-> save.

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %% [markdown]
# ### Define a function to load the training and testing data:

# %%
def read_csv():
  """Read CSV file data into a pandas dataframe

    Return:
          train_data: Dataframe containing training features
          test_data:  Dataframe containing testing features
  """
  ### Read the CSV Data - No need to add anything here!
  csv_fpath     = 'https://storage.googleapis.com/ai_evaluation/PAP/pap_usage.csv'
  pap_data      = pd.read_csv(csv_fpath, index_col=0)

  train_data, test_data = train_test_split(pap_data, test_size=0.2)


  return train_data, test_data

# %%
### TODO: Call read_csv to get train_data and test_data
train_data_pd, test_data_pd = read_csv()
train_data_pd.head()
# Out:
#         Age Sex  AHI       Day 1       Day 2       Day 3       Day 4  \
# UID
# 62276    60   M   70  348.000000  457.000000  291.000000  415.000000
# 78088    65   M   31  534.000000  409.000000  381.000000  461.000000
# 105701   69   F   22  435.283333  484.033333  389.716667  508.733333
# 99713    77   M   27  154.000000  330.000000  383.000000  313.000000
# 25846    59   M   48  439.000000  555.000000  542.000000  478.000000
#
#              Day 5   Day 6       Day 7  ...     Day 446     Day 447  \
# UID                                     ...
# 62276   427.000000  403.00  451.000000  ...  397.000000  496.000000
# 78088   297.000000  463.00  470.000000  ...  593.000000  490.000000
# 105701  362.683333  260.35  405.166667  ...  494.483333  456.166667
# 99713   415.000000  401.00  312.000000  ...  616.000000  588.000000
# 25846   420.000000  516.00  481.000000  ...  485.000000  530.000000
#
#            Day 448     Day 449     Day 450     Day 451     Day 452  \
# UID
# ...

# %%
smallSet = True
numberOfUser = 100

# %%
if smallSet:
  train_data = train_data_pd[0:numberOfUser]
  test_data = test_data_pd[0:numberOfUser]
else:
  train_data = train_data_pd
  test_data = test_data_pd

# %%
train_data.shape
# Out:
# (100, 458)

# %%
test_data.shape
# Out:
# (100, 458)

# %% [markdown]
# ### Define a function that preprocesses the data:
#
# The function below should be able to take the train or test dataframe and restructure it into input and output arrays for the forecasting task.
# <br><br>
#
# The input array should be defined such that for each patient, the 455 days of CPAP usage are split into seperate windows of size `window`.
# <br><br>
#
# The output array should be defined as the next window of CPAP usage that the model should forecast. The size of this window should be defined by the variable `look`.
# <br><br>
#
# i.e. let U<sub>i</sub> be the CPAP usage for day i, then the function below should produce the following (for a single patient):
# <br><br>
# x = [<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[U<sub>0</sub>, U<sub>1</sub>, ..., U<sub>window</sub>],<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [U<sub>1</sub>, U<sub>2</sub>, ..., U<sub>window+1</sub>],<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ...<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [U<sub>455-window-look-1</sub>, ..., U<sub>455-look-1</sub>]<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;]
# <br><br>
# y = [<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [U<sub>window</sub>, U<sub>window+1</sub>, ..., U<sub>window+look</sub>],<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [U<sub>window+1</sub>, U<sub>window+2</sub>, ..., U<sub>window+1+look</sub>],<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ...<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[U<sub>455-look-1</sub>, ..., U<sub>455-1)</sub>]<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;]
# <br><br>
#
# Note: You should define `window=30` and `look=30`.

# %%
def preprocess_data(df, window, look):
  """ Restructures the data for the forecasting tasks.

  Args:
    df (pd.DataFrame): A dataframe containing the number of minutes of CPAP usage per day
    window (int): An integer specifing the number of days to use for forecasting
    look (int): An integer specifing the number of days ahead the model should forecast

  Returns:
    x (np.array): A numpy array containing all examples to use for forecasting. 
              Each example represents an array of length `window` that 
              containes the number of CPAP usage days to use for forecasting.
    y (np.array): A numpy array containing all labels for forecasting. Each example represents
        an arry of length `look` that contains the number of CPAP usage days to forcast.
  """
  #### TODO: Implement the function here
  df = df.filter(regex='Day', axis=1)
  num_days = len(df.columns)-6
  nub_user = df.shape[0]
  x = np.zeros((nub_user,num_days - window - look, window))
  y = np.zeros((nub_user,num_days - window -look, look))
  for i in range(df.shape[0]):
    df_temp = train_data.iloc[i][9:]
    in_start = 0
    for j in range(x.shape[1]):
      in_end = in_start + window
      out_end = in_end + look
      if out_end <= num_days:
        x[i,j,:] = np.array([df_temp[in_start:in_end]])
        y[i,j,:] = np.array([df_temp[in_end:out_end]])
      in_start += 1
  return x, y

# %%
### TODO: Define window and look below and call preprocess_data twice to get x_train, y_train, and x_test, y_test
window=30
look=30
x_train,y_train = preprocess_data(train_data,window,look)
##Garbage Collect
gc.collect()
x_test,y_test = preprocess_data(test_data,window,look)
##Garbage Collect
gc.collect()
# Out:
# 0

# %%
x_train.shape
# Out:
# (100, 389, 30)

# %%
y_train.shape
# Out:
# (100, 389, 30)

# %%
x_test.shape
# Out:
# (100, 389, 30)

# %%
y_test.shape
# Out:
# (100, 389, 30)

# %% [markdown]
# ### Define feature and label transformations:
# Below you can (but you don't have to) define two functions, one for the features and one for the labels. The functions should apply any transformations that you think would be beneficial for the forecasting tasks.
#
# ***Tip: Since it will probably be difficult for the models to forecast raw hours or minutes of CPAP usage for all 30 days based on the previous 30 days, we recommend you think of a way to compress the next 30 days of CPAP usage into an easier output for the model. For example, one option is to compress the next 30 days of CPAP usage into 3 values, one value represents the number of days the patient used the CPAP for 0 hours, the second value represents the number of days the patient used the CPAP for < 4 hours, and the third value represents the number of days the patient used the CPAP for > 4 hours.***
#
# ***Note: The only thing you should not change about the features and labels is that the features should always represent `window` days of CPAP usage data and the labels should always represent the next `look` days of CPAP usage data.***

# %%
def transform_features(x):
  """ Apply feature transformations.

  Args:
    x (np.array): The feature data.

  Returns:
    x_transformed (np.array): Transformed features
  """
  x_transformed = np.zeros((x.shape[0],x.shape[1], x.shape[2], 4))
  for i in range(x.shape[0]):
    for j in range(x.shape[1]):
      for k in range(x.shape[2]):
        x_transformed[i,j,k,0]=np.float16(x[i,j,k])
        if x[i,j,k] == 0:
          x_transformed[i,j,k,1]=np.float16(1)
        else:
          x_transformed[i,j,k,1]=np.float16(0)
        
        if x[i,j,k] >=0 and x[i,j,k] <= 240:
          x_transformed[i,j,k,2]=np.float16(1)
        else:
          x_transformed[i,j,k,2]=np.float16(0)

        if x[i,j,k] > 240:
          x_transformed[i,j,k,3]=np.float16(1)
        else:
          x_transformed[i,j,k,3]=np.float16(0)
  return x_transformed

def transform_labels(y):
  """ Apply label transformations.

  Args:
    y (np.array): The label data.

  Returns:
    y_transformed (np.array): Transformed labels
  """
  y_transformed = np.zeros((y.shape[0],y.shape[1], y.shape[2], 4))
  for i in range(y.shape[0]):
    for j in range(y.shape[1]):
      for k in range(y.shape[2]):
        y_transformed[i,j,k,0]=y[i,j,k]
        if y[i,j,k] == 0:
          y_transformed[i,j,k,1]=1
        else:
          y_transformed[i,j,k,1]=0
        
        if y[i,j,k] >0 and y[i,j,k] <= 240:
          y_transformed[i,j,k,2]=1
        else:
          y_transformed[i,j,k,2]=0

        if y[i,j,k] > 240:
          y_transformed[i,j,k,3]=1
        else:
          y_transformed[i,j,k,3]=0
  return y_transformed

# %%
### TODO: Call transform_features for x_train and x_test, and call transform_labels for y_train and y_test
ts = time.time()
x_train_transformed = transform_features(x_train)
##Garbage Collect
gc.collect()
print('x_train transfortook {0}s'.format(time.time()-ts))
# Out:
# x_train transfortook 6.007688045501709s

# %%
ts = time.time()
x_test_transformed = transform_features(x_test)
##Garbage Collect
gc.collect()
print('x_test transfortook {0}s'.format(time.time()-ts))
# Out:
# x_test transfortook 7.594832420349121s

# %%
#y_train_transformed = transform_labels(y_train)
##Garbage Collect
#gc.collect()

# %%
#y_test_transformed = transform_labels(y_test)
##Garbage Collect
#gc.collect()

# %%
x_train_transformed.shape
# Out:
# (100, 389, 30, 4)

# %% [markdown]
# ### Define a function that evaluates model performance:
# The function below should produce a scatter plot with an overlapping deming regression line (please include the slope and intercept values for the regression line as well) and a y=x line. The x axis should represent the forecasted CPAP usage data and the y axis should represent the observed (true) CPAP usage data.
# <br><br>
# The scatter plot might look something like this:
# <br><br>
# ![cpap_usage_forecasting_dummy_ex.png](data:image/png;base64,...)
# <br>
# ***Note: The units of the y and x axes don't necessarily need to be in units of hours. They can be in whatever unit that was generated by the transform_lables function. For example, if you applied a labels transformation that converts the labels into units of days, the y and x axes can be in units of days.***

# %%
def target_function(p, x):
    m, c = p
    return m*x + c

def demingRegressor(x,y):
  #  model fitting.
  odr_model = odr.Model(target_function)
 
  # Create a Data object using sample data created.
  data = odr.Data(x, y)
 
  # Set ODR with the model and data.
  ordinal_distance_reg = odr.ODR(data, odr_model,beta0=[0.2, 1.])
 
  # Run the regression.
  output = ordinal_distance_reg.run()
  return output

# %%
def plot_usage(y_true, y_pred):
  """ Produces a scatter plot and a deming regression line comparing y_true and y_pred.


  Args:
    y_true (np.array): A numpy array with the true values
    y_pred (np.array): A numpy array with the predicted values
  """
  fig, ax = plt.subplots(figsize=(6, 6))
  m, b = np.polyfit(y_pred, y_true, 1)
  
  #add linear regression line to scatterplot 
  plt.plot(y_pred, m*y_pred+b, linestyle='dashed', lw=3, color='black')
  
  sns.regplot(x=y_pred, y=y_true,ci=None,line_kws={'ls':'--','lw': 3})
  demingRegression = demingRegressor(y_pred, y_true)
  m_deming = str("{:.2f}".format(demingRegression.beta[0]))
  c_deming = str("{:.2f}".format(demingRegression.beta[1]))
  sns.regplot(x=y_pred, y=target_function(demingRegression.beta,y_pred),ci=None,line_kws={'lw': 3},color='red')
  ax.set(ylabel='Observed CPAP Usees [hours]', xlabel='Predicted CAPA Usages [hours]')
  ax.text(0.1, 0.9, 'm='+m_deming, horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
  ax.text(0.1, 0.85, 'c='+c_deming, horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
  plt.show()
  #### TODO: Implement the function here

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def evaluate_forecasts(y_true, y_pred):
  scores = list()
  # calculate an RMSE score for each day
  for i in range(y_true.shape[1]):
    # calculate mse
    mse = mean_squared_error(y_true[:, i], y_pred[:, i])
    # calculate rmse
    rmse = sqrt(mse)
    # store
    scores.append(rmse)
  # calculate overall RMSE
  s = 0
  for row in range(y_true.shape[0]):
    for col in range(y_true.shape[1]):
      s += (y_true[row, col] - y_pred[row, col])**2
  score = sqrt(s / (y_true.shape[0] * y_true.shape[1]))
  return score, scores

# %%
##Garbage Collect
gc.collect()
# Out:
# 66

# %% [markdown]
# #Task 3 - Implement a Naive (not Bayes) PAP Adherence Forecasting Algorithm

# %% [markdown]
# ### Define a function that implements the naive forecasting method:
# Here you will implement a basic forecasting model that assumes the CPAP usage data of the previous days is equal to the CPAP usage data of the trailing days.
#
# i.e.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if:<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;x = [U<sub>i</sub>, U<sub>i+1</sub>, ..., U<sub>i+window</sub>]&nbsp;&nbsp;&nbsp;&&nbsp;&nbsp;&nbsp;y_true=[U<sub>i+window</sub>, U<sub>i+window+1</sub>, ..., U<sub>i+window+look</sub>]<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;then:<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;y_pred = [U<sub>i+window-look</sub>, U<sub>i+window-look+1</sub>, ..., U<sub>i+window</sub>]<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;where i > look

# %%
def naive_forecasting(x):
  """ Produces y_pred by assuming that the CPAP usage from the previous days
  is equal to the CPAP usage from the trailing days.


  Args:
    x (np.array): A numpy array with CPAP usage data
  
  Returns:
    y_pred (np.array): A numpy array with the predicted CPAP usage data
  """
  #### TODO: Implement the function here
  y_pred = np.zeros(x.shape)
  for i in range(y_pred.shape[0]):
    for j in range(y_pred.shape[1]):
      y_pred[i,j,:] = x_train[i,j,-1]
  return y_pred

# %%
#### TODO: Pass x_train into naive_forecasting() to get y_pred
y_predicted = naive_forecasting(x_train)
y_predicted.shape
# Out:
# (100, 389, 30)

# %% [markdown]
# ### Evaluate the naive method:
# Use the `plot_usage` function you previously implemented to test this method's performance.

# %%
#### TODO: Pass y_true and y_pred to plot_usage to generate the comparison plot
plot_usage(y_train.flatten()/60, y_predicted.flatten()/60)

# %% [markdown]
# MSE graph for one user

# %%
score, scores = evaluate_forecasts(y_train[0,:,:], y_predicted[0,:,:])

# %%
days = [x for x in range(30)]
plt.plot(days, scores, marker='o', label='Naive')
plt.show()

# %% [markdown]
# #Task 4 - Train a Machine Learning Model for PAP Adherence Forecasting:

# %% [markdown]
# ### Define the machine learning model:
# Choose a machine learning algorithm from Scikit-learn or other non-deep-learning library and define it in `get_ml_model()`.

# %%
def get_ml_model(module_name, model_class, **hparams):
  """ Returns an intialized ML model.


  Args:
    module_name (str): The name of the module to use, e.g. `sklearn.linear_model`
    module_class (str): The name of the model class to use, e.g. `LogisticRegression`
    **hparams (dict): a dictionary containing all necessary hparams for the chosen model
  
  Returns:
    model : An initialized model
  """
  parent_module = importlib.import_module(module_name)
  model_class = eval('parent_module.' + str(model_class))
  hyper_params = {'max_depth': 9, 
                'gamma': 5, 
                'subsample': 0.7, 
                'colsample_bytree':0.8, 
                'learning_rate': 0.3,
                'max_bin' : 512
               }
  model = model_class(hyper_params)
  return model

# %%
#### TODO: Get the ML model here
ml_model = get_ml_model('xgboost','XGBRegressor')
ml_model
# Out:
# XGBRegressor(max_depth={'colsample_bytree': 0.8, 'gamma': 5,
#                         'learning_rate': 0.3, 'max_bin': 512, 'max_depth': 9,
#                         'subsample': 0.7})

# %% [markdown]
# ### Train the machine learning model:
# Use the initialized model from above, as well as x_train and y_train to train the model in `train_ml_model()`.

# %%
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from numpy import array

# %%
def train_ml_model(model, x_train, y_train):
  """ Returns a trained ML model.

  Args:
    model : An initialized model
    x_train (np.array): A numpy array containing the input features
    y_train (np.array): A numpy array containing the output labels
  
  Returns:
    model : A trained model
  """
  ts = time.time()
  xgb = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
  steps = list()
  steps.append(('standardize', StandardScaler()))
  steps.append(('normalize', MinMaxScaler()))
  steps.append(('model', xgb))
  
  # create pipeline
  pipeline = Pipeline(steps=steps)
  pipeline.fit(x_train.reshape(x_train.shape[0]*x_train.shape[1],x_train.shape[2]),y_train.reshape(y_train.shape[0]*y_train.shape[1],y_train.shape[2]))
  print('Training took: {0}s'.format(time.time()-ts))
  return pipeline

# %%
# make a recursive multi-step forecast
def forecast(model, input_x, n_input):
  yhat_sequence = list()
  input_data = [x for x in input_x]
  #print(input_data)
  #input_data = input_x
  for j in range(30):
		# prepare the input data
    X = array(input_data[-n_input:]).reshape(1, n_input)
		# make a one-step forecast
    yhat = model.predict(X)[0]
		# add to the result
    yhat_sequence.append(yhat)
		# add the prediction to the input
    input_data.append(yhat)
  return yhat_sequence

# %%
#### TODO: call train_ml_model() to train the model
y_train_single = y_train[:,:,0].reshape(y_train.shape[0],y_train.shape[1],1)
xgb_trained = train_ml_model(ml_model,x_train,y_train_single)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py:613: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# Training took: 46.144808530807495s

# %%
y_xgb_pred = np.zeros(x_train.shape)
for i in range(y_xgb_pred.shape[0]):
  for j in range(y_xgb_pred.shape[1]):
    y_xgb_pred[i,j,:] = forecast(xgb_trained,x_train[i,j,:],30)

# %%
y_xgb_test_pred = np.zeros(x_test.shape)
for i in range(y_xgb_test_pred.shape[0]):
  for j in range(y_xgb_test_pred.shape[1]):
    y_xgb_test_pred[i,j,:] = forecast(xgb_trained,x_test[i,j,:],30)

# %%
y_test.shape
# Out:
# (100, 389, 30)

# %% [markdown]
# ### Evaluate model performance:
# Pass x_test to the trained model to generate y_pred and plot the model's performance using `plot_usage()`.

# %%
### TODO: Use x_test and the trained model to generate y_pred. Then call plot_usage(y_true, y_pred).
plot_usage(y_test.flatten()/60, y_xgb_test_pred.flatten()/60)

# %%
score_xgb, scores_xgb = evaluate_forecasts(y_test[0,:,:], y_xgb_test_pred[0,:,:])

# %%
days = [x for x in range(30)]
plt.plot(days, scores_xgb, marker='o', label='Naive')
plt.show()

# %% [markdown]
# #Task 5 - Train a Deep Learning Model for PAP Adherence Forecasting:

# %% [markdown]
# ###Define the model architecture:
# Define a `get_dl_model()` function utilizing `tf.keras`. You should design a model architecture that is appropriate for this forecasting task. The template below already has 4 main hyperparameters (input_shape, optimizer, lr, and loss), feel free to add additional ones!

# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation

# %%
def get_dl_model(input_shape, optimizer, lr, loss, strategy):
  """ Returns a compiled DL keras model.


  Args:
    input_shape (tuple): The shape of the input
    optimizer (str): The name of the keras supported optimizer to use for training
    lr (float): Learning rate to use for training
    loss (str): The name of keras supported loss to use for training
  
  Returns:
    model (tf.keras.Functional): A compiled keras model
  """
  with strategy.scope():
    inputs = tf.keras.Input(batch_shape=input_shape, dtype=tf.float32)
    #### TODO: Implement the rest of the model here

    n_steps_in = input_shape[0]
    n_features = input_shape[1]
    n_steps_out = 30
    # define model
    model = Sequential()
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
    model.add(LSTM(50, activation='relu'))
    model.add(Dense(n_steps_out))
    model.add(Activation('linear'))    
    model.summary() # Don't remove this
    optimizer_obj = tf.keras.optimizers.get({'class_name': optimizer, 'config': {'learning_rate': lr}}) # Don't remove this
    model.compile(optimizer=optimizer_obj, loss=loss) # Don't remove this
    return model

# %%
optimizer = 'adam'
lr = 0.01
loss = 'mse'

# %%
#### TODO: Get the DL model here
dl_model = get_dl_model((30, 4),optimizer,lr,'mse',strategy)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 50)            11000
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 30)                1530
#
#  activation (Activation)     (None, 30)                0
#
# ...
# Total params: 32,730
# Trainable params: 32,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model:
# Define the necessary hyperparameters, get the model, and train it using x_train and y_train.
#
# In order to ensure that you are able to iterate quickly on various model architectures, you should use TPUs to train the model.
#
# If you are not familiar with TPU training, checkout the following useful resources:
# 1. https://www.tensorflow.org/guide/distributed_training
# 2. https://www.tensorflow.org/guide/tpu
# 3. https://www.tensorflow.org/tutorials/distribute/keras

# %%
def train_dl_model(model, x_train, y_train, batch_size, epochs,test_X, test_y):
  """ Returns a trained DL model.

  Args:
    model : A compiled Keras model
    x_train (np.array): A numpy array containing the input features
    y_train (np.array): A numpy array containing the output labels
  
  Returns:
    model : A trained model
  """
  history = model.fit(x_train , y_train , epochs=epochs , steps_per_epoch=batch_size , verbose=1 ,validation_data=(test_X, test_y) ,shuffle=False)
  return model

# %%
x_train.shape
# Out:
# (100, 389, 30)

# %%
x_train_transformed.shape
# Out:
# (100, 389, 30, 4)

# %%
y_train.shape
# Out:
# (100, 389, 30)

# %%
input_x_train = x_train_transformed.reshape(x_train_transformed.shape[0]*x_train_transformed.shape[1],x_train_transformed.shape[2],x_train_transformed.shape[3])
input_x_train.shape
# Out:
# (38900, 30, 4)

# %%
input_y_train = y_train.reshape(y_train.shape[0]*y_train.shape[1],y_train.shape[2])
input_y_train.shape
# Out:
# (38900, 30)

# %%
val_x_test = x_test_transformed.reshape(x_test_transformed.shape[0]*x_test_transformed.shape[1],x_test_transformed.shape[2],x_test_transformed.shape[3])
val_x_test.shape
# Out:
# (38900, 30, 4)

# %%
val_y_test = y_test.reshape(y_test.shape[0]*y_test.shape[1],y_test.shape[2])
val_y_test.shape
# Out:
# (38900, 30)

# %%
### TODO: Call train_dl_model to train the model.
train_dl_model(dl_model,input_x_train,input_y_train,25,60,val_x_test,val_y_test)
# Out:
# Epoch 1/60
# 25/25 [==============================] - 19s 542ms/step - loss: 812727.5000 - val_loss: 161126.6875
# Epoch 2/60
# 25/25 [==============================] - 11s 454ms/step - loss: 125222.2812 - val_loss: 60245.4375
# Epoch 3/60
# 25/25 [==============================] - 11s 462ms/step - loss: 37338.6406 - val_loss: 26203.1055
# Epoch 4/60
# 25/25 [==============================] - 11s 457ms/step - loss: 39366.2930 - val_loss: 48625.3516
# Epoch 5/60
# 25/25 [==============================] - 11s 460ms/step - loss: 47919.3945 - val_loss: 71578.6562
# Epoch 6/60
# 25/25 [==============================] - 11s 453ms/step - loss: 68695.0078 - val_loss: 35704.6602
# Epoch 7/60
# 25/25 [==============================] - 11s 449ms/step - loss: 55572.7930 - val_loss: 36293.1250
# Epoch 8/60
# 25/25 [==============================] - 11s 443ms/step - loss: 23442.9043 - val_loss: 18715.1445
# Epoch 9/60
# ...

# %% [markdown]
# ### Evaluate model performance:
# Pass x_test into model.predict() to generate y_pred and plot the model's performance using plot_usage.

# %%
### TODO: Call model.predict(x_test) to generate y_pred. Then call plot_usage(y_true, y_pred). 
y_dl_pred = dl_model.predict(val_x_test)

# %%
y_dl_pred.shape
# Out:
# (38900, 30)

# %%
val_y_test.shape
# Out:
# (38900, 30)

# %%
plot_usage(val_y_test.flatten()/60, y_dl_pred.flatten()/60)

# %%
score_dl, scores_dl = evaluate_forecasts(y_test[0,:,:], y_xgb_test_pred[0,:,:])

# %%
days = [x for x in range(30)]
plt.plot(days, scores_dl, marker='o', label='Naive')
plt.show()

# %% [markdown]
# #Task 6 - Discussion:

# %% [markdown]
# ### Compare model performance:
# Generate a final figure that includes all three plots generated above for easy comparison. You should use the matplotlib subplots functionality.

# %%
### TODO: Generate the plots here
plot_usage(y_train.flatten()/60, y_predicted.flatten()/60)
plot_usage(y_test.flatten()/60, y_xgb_test_pred.flatten()/60)
plot_usage(val_y_test.flatten()/60, y_dl_pred.flatten()/60)

# %% [markdown]
# ### Answer the following discussion questions:
# You can edit this block with your responses.
# 1. What did you find challenging in this technical evaluation?
#
# The number of total users including traing and testing is over 10K so when building sliding wondow matrix it is becoming order of millon because of that the system becme unstable and repetedly getting memory error. Also experience TPU availability problem.
#
# Due to time constrain couldn't try multi thread pipeline for training and testing.
# 2. Explain why you chose the ML model that you used in Task 4
#   XGBoost is an implementation of the gradient boosting ensemble algorithm for classification and regression.
# 3. Justify the design of the deep learning architecture that you used in Task 5.
#
# The Long short-term memory recurrent neural networks are capable of automatically learning features from sequence data, support multiple-variate data, and can output a variable length sequences that can be used for multi-step forecasting.
#
# Because of system and time constrain design a simple LSTM model.
#
# 4. Which method worked the best and why do you think that was the case?
# As per the rusult looks like XGBoost but in various run with TPU, I observed the deeplearnig model worked best.
#
# 5. How would you use the best model that you created in this evaluation to flag patients that are at risk for becoming non-compliant with the CPAP machine?
#
# As per the CAPA compliant user should use 4 hours for at least 70% of time. So from the best modelpredict the CAPA uses and if it fall above target flag as non-compliant.
